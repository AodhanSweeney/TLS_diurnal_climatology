# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gpsro_tools

# %% [markdown]
# # Import Occultation Data

# %%
# Import occultation data
#import october with data on which year of occultation was taken
september_year_info = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_cosmic_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_cosmic_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_cosmic_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_metopa = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_metop_A_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_metopa = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_metop_A_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_metopa = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_metop_A_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_metopb = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_metop_B_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_metopb = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_metop_B_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_metopb = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_metop_B_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_grace = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_grace_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_grace = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_grace_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_grace = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_grace_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_tsx = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_tsx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_tsx = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_tsx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_tsx = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_tsx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_kompsat5 = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_kompsat5_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_kompsat5 = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_kompsat5_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_kompsat5 = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_kompsat5_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_paz = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_paz_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_paz = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_paz_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_paz = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_paz_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_cosmic2 = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_cosmic2_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_cosmic2 = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_cosmic2_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_cosmic2 = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_cosmic2_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_sacc = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_sacc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_sacc = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_sacc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_sacc = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_sacc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_tdx = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_tdx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_tdx = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_tdx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_tdx = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_tdx_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)

september_year_info_metopc = np.load('/usb/monthly_diurnal_cycle_data_occultations/september_metopc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
october_year_info_metopc = np.load('/usb/monthly_diurnal_cycle_data_occultations/october_metopc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)
november_year_info_metopc = np.load('/usb/monthly_diurnal_cycle_data_occultations/november_metopc_diurnal_cycles_TLS_year_info.npy', allow_pickle=True)


oct_data = np.concatenate((october_year_info.T, october_year_info_metopa.T, october_year_info_metopb.T, 
                           october_year_info_grace.T, october_year_info_tsx.T, october_year_info_kompsat5.T, 
                           october_year_info_cosmic2.T, october_year_info_paz.T, october_year_info_sacc.T, 
                           october_year_info_tdx.T, october_year_info_metopc.T))
nov_data = np.concatenate((november_year_info.T, november_year_info_metopa.T, november_year_info_metopb.T,
                           november_year_info_grace.T, november_year_info_tsx.T, november_year_info_kompsat5.T, 
                           november_year_info_cosmic2.T, november_year_info_paz.T, november_year_info_sacc.T, 
                           november_year_info_tdx.T, november_year_info_metopc.T))
sep_data = np.concatenate((september_year_info.T, september_year_info_metopa.T, september_year_info_metopb.T, 
                           september_year_info_grace.T, september_year_info_tsx.T, september_year_info_kompsat5.T, 
                           september_year_info_cosmic2.T, september_year_info_paz.T, september_year_info_sacc.T, 
                           september_year_info_tdx.T, september_year_info_metopc.T))

#create dataframes for season
oct_year_info_df = pd.DataFrame(oct_data, columns=['Lat', 'Lon', 'Year', 'Day', 'Hour', 'Temp'])
nov_year_info_df = pd.DataFrame(nov_data, columns=['Lat', 'Lon', 'Year', 'Day', 'Hour', 'Temp'])
sep_year_info_df = pd.DataFrame(sep_data, columns=['Lat', 'Lon', 'Year', 'Day', 'Hour', 'Temp'])

# Round hours to nearest integer
to_int_hour = lambda x: int(x)
sep_year_info_df["Hour"] = sep_year_info_df.Hour.map(to_int_hour)
oct_year_info_df["Hour"] = oct_year_info_df.Hour.map(to_int_hour)
nov_year_info_df["Hour"] = nov_year_info_df.Hour.map(to_int_hour)

# %% [markdown]
# # Import ERA-5 Data

# %%
era_5_oct_06_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2006_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_07_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2007_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_08_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2008_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_09_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2009_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_10_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2010_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_11_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2011_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_12_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2012_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_13_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2013_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_14_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2014_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_15_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2015_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_16_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2016_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_17_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2017_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_18_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2018_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_19_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2019_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_oct_20_5x10 = np.load('../../ERA_5_monthly_TLS_maps/october_2020_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)

era_5_nov_06_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2006_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_07_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2007_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_08_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2008_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_09_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2009_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_10_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2010_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_11_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2011_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_12_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2012_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_13_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2013_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_14_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2014_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_15_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2015_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_16_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2016_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_17_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2017_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_18_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2018_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_19_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2019_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_nov_20_5x10 = np.load('../../ERA_5_monthly_TLS_maps/november_2020_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)

era_5_sep_06_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2006_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_07_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2007_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_08_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2008_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_09_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2009_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_10_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2010_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_11_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2011_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_12_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2012_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_13_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2013_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_14_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2014_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_15_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2015_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_16_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2016_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_17_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2017_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_18_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2018_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_19_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2019_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)
era_5_sep_20_5x10 = np.load('../../ERA_5_monthly_TLS_maps/september_2020_ERA_5_daily_zonal_mean_TLS_map_5_10.npy', allow_pickle=True)

era_5_sep_06_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_06_5x10)
era_5_sep_07_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_07_5x10)
era_5_sep_08_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_08_5x10)
era_5_sep_09_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_09_5x10)
era_5_sep_10_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_10_5x10)
era_5_sep_11_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_11_5x10)
era_5_sep_12_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_12_5x10)
era_5_sep_13_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_13_5x10)
era_5_sep_14_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_14_5x10)
era_5_sep_15_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_15_5x10)
era_5_sep_16_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_16_5x10)
era_5_sep_17_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_17_5x10)
era_5_sep_18_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_18_5x10)
era_5_sep_19_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_19_5x10)
era_5_sep_20_5x10_df = gpsro_tools.era5_df_switcher(era_5_sep_20_5x10)

era_5_oct_06_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_06_5x10)
era_5_oct_07_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_07_5x10)
era_5_oct_08_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_08_5x10)
era_5_oct_09_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_09_5x10)
era_5_oct_10_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_10_5x10)
era_5_oct_11_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_11_5x10)
era_5_oct_12_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_12_5x10)
era_5_oct_13_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_13_5x10)
era_5_oct_14_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_14_5x10)
era_5_oct_15_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_15_5x10)
era_5_oct_16_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_16_5x10)
era_5_oct_17_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_17_5x10)
era_5_oct_18_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_18_5x10)
era_5_oct_19_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_19_5x10)
era_5_oct_20_5x10_df = gpsro_tools.era5_df_switcher(era_5_oct_20_5x10)

era_5_nov_06_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_06_5x10)
era_5_nov_07_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_07_5x10)
era_5_nov_08_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_08_5x10)
era_5_nov_09_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_09_5x10)
era_5_nov_10_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_10_5x10)
era_5_nov_11_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_11_5x10)
era_5_nov_12_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_12_5x10)
era_5_nov_13_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_13_5x10)
era_5_nov_14_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_14_5x10)
era_5_nov_15_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_15_5x10)
era_5_nov_16_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_16_5x10)
era_5_nov_17_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_17_5x10)
era_5_nov_18_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_18_5x10)
era_5_nov_19_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_19_5x10)
era_5_nov_20_5x10_df = gpsro_tools.era5_df_switcher(era_5_nov_20_5x10)


era_5_sep_df = pd.concat([era_5_sep_06_5x10_df, era_5_sep_07_5x10_df, era_5_sep_08_5x10_df, era_5_sep_09_5x10_df, 
                          era_5_sep_10_5x10_df, era_5_sep_11_5x10_df, era_5_sep_12_5x10_df, era_5_sep_13_5x10_df, 
                          era_5_sep_14_5x10_df, era_5_sep_15_5x10_df, era_5_sep_16_5x10_df, era_5_sep_17_5x10_df, 
                          era_5_sep_18_5x10_df, era_5_sep_19_5x10_df, era_5_sep_20_5x10_df])
era_5_oct_df = pd.concat([era_5_oct_06_5x10_df, era_5_oct_07_5x10_df, era_5_oct_08_5x10_df, era_5_oct_09_5x10_df, 
                          era_5_oct_10_5x10_df, era_5_oct_11_5x10_df, era_5_oct_12_5x10_df, era_5_oct_13_5x10_df, 
                          era_5_oct_14_5x10_df, era_5_oct_15_5x10_df, era_5_oct_16_5x10_df, era_5_oct_17_5x10_df, 
                          era_5_oct_18_5x10_df, era_5_oct_19_5x10_df, era_5_oct_20_5x10_df])
era_5_nov_df = pd.concat([era_5_nov_06_5x10_df, era_5_nov_07_5x10_df, era_5_nov_08_5x10_df, era_5_nov_09_5x10_df, 
                          era_5_nov_10_5x10_df, era_5_nov_11_5x10_df, era_5_nov_12_5x10_df, era_5_nov_13_5x10_df, 
                          era_5_nov_14_5x10_df, era_5_nov_15_5x10_df, era_5_nov_16_5x10_df, era_5_nov_17_5x10_df, 
                          era_5_nov_18_5x10_df, era_5_nov_19_5x10_df, era_5_nov_20_5x10_df])
# Out:
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   era_5_df_pos_lons['Lon'] = era_5_df_pos_lons['Lon'] - 180.
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   era_5_df_neg_lons['Lon'] = era_5_df_neg_lons['Lon'] + 180

# %% [markdown]
# # Begin processing

# %%
daily_era5_removed_and_bias_removed_oct = gpsro_tools.background_and_bias_remover(oct_year_info_df, era_5_oct_df)
daily_era5_removed_and_bias_removed_nov = gpsro_tools.background_and_bias_remover(nov_year_info_df, era_5_nov_df)
daily_era5_removed_and_bias_removed_sep = gpsro_tools.background_and_bias_remover(sep_year_info_df, era_5_sep_df)
# Out:
# 2006
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_of_occultations["latbin"] = year_of_occultations.Lat.map(to_bin_lat)
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_of_occultations['lonbin'] = year_of_occultations.Lon.map(to_bin_lon)
# ...

# %% [markdown]
# #### Regroup data and drop NaN values

# %%
data_all_mean_stuff_removed = pd.concat([daily_era5_removed_and_bias_removed_sep, 
                                         daily_era5_removed_and_bias_removed_oct,
                                         daily_era5_removed_and_bias_removed_nov])
data_all_mean_stuff_removed.dropna(subset=["Temp"], inplace=True)

# %% [markdown]
# <h1> Now create the diurnal cycles

# %%
cleaned_diurnal_cycle_data = gpsro_tools.box_mean_remover(data_all_mean_stuff_removed)
diurnal_cycles_by_lat, diurnal_cycles_in_boxes = gpsro_tools.diurnal_binner(cleaned_diurnal_cycle_data)
# Out:
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_lon_box.dropna(subset = ["Temp"], inplace=True)
# /home/disk/p/aodhan/cosmic/diurnal_cycle_corrections/sampling_biases/TLS_diurnal_climatology/gpsro_tools.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_lon_box['Temp'] = lat_lon_box['Temp'] - lat_lon_box.Temp.mean()

# %%
np.save('SON_GPSRO_5_10_boxes_diurnal_cycles', diurnal_cycles_in_boxes)
